# %% [markdown]
# <a href="https://colab.research.google.com/github/ft-abhx/Machine-Learning-Worksheets/blob/main/Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![MLoriginal.png](data:image/png;base64,...)

# %% [markdown]
# # Topics
# 1.   Types of Clustering
# 2.   Steps in Clustering
# 1.   K-Means Clustering
# 2.   Advantages and Disadvantages
# 5. Implementation in Python

# %% [markdown]
# # 1. Types of Clustering
#
# **Centroid Based Clustering:** Centroid-based clustering organizes the data into non-hierarchical clusters, in contrast to hierarchical clustering defined below. k-means is the most widely-used centroid-based clustering algorithm. Centroid-based algorithms are efficient but sensitive to initial conditions and outliers. This course focuses on k-means because it is an efficient, effective, and simple clustering algorithm.
#
# **Density-based Clustering:**  Density-based clustering connects areas of high example density into clusters. This allows for arbitrary-shaped distributions as long as dense areas can be connected. These algorithms have difficulty with data of varying densities and high dimensions.
#
#
#
#
# **Distribution-based Clustering:**  The distribution-based algorithm clusters data into three Gaussian distributions. As distance from the distribution's center increases, the probability that a point belongs to the distribution decreases.
#
#
# **Hierarchical Clustering:** Hierarchical clustering creates a tree of clusters.

# %% [markdown]
# Our topic of interest is K-Means Clustering (Centroid Based Clustering)
# # 2. Steps in Clustering
#
#
# 1.   Preprocess Data (Removing or Replacing or Scaling )
# 2.   Create Similarity Metric (Ex: Eucledian Distance)
# 3. Run Clustering Algorithm (Stopping criteria can be number of iterations)
# 4. Interpret Results (Visualizing using matplotlib or other libraries)

# %% [markdown]
# # 3. K-Means Clustering
# To group data into $k$ clusters, K-Means perform as follows,
#
# **Steps**
#
#
# 1.   Randomly chose centroid for each cluster
# 2.   Assign each sample to closest centroid based on Similarity Metric (Eucledian Distance)
# 3. For each cluster, recompute centroid, by taking average of all samples in that cluster
# 4. Repeat 2 and 3 until stopping criteria is met (Ex : 50 iterations)

# %% [markdown]
# # 4. Simple Numerical Example
# ![K-Means.PNG](data:image/png;base64,...)
#
# The example shows the result after iteration $1$.
#
# This process will be repeated till stopping criteria is met

# %% [markdown]
# #5. Implementing the simple example in Python

# %%
from sklearn.cluster import KMeans
import numpy as np
X = np.array([[1, 2], [1, 4], [5, 3],[5, 6]]) #Samples
start1=np.array([[1,2],[1,4]]) #Centroid-1
kmeans = KMeans(n_clusters=2,max_iter=1,init=start1).fit(X)  #Defining and fitting K-means

print("Cluster allocation of each samples: ",kmeans.labels_,"\n") #Will print Cluster allocation of each samples
print("Prediction of unseen data: ",kmeans.predict([[0, 0], [12, 3]]),"\n") #Predicting for unseen data
print("Centroids after iteration 1: ",kmeans.cluster_centers_) #Centroids after iteration 1
# Out:
# Cluster allocation of each samples:  [0 1 0 1]
#
# Prediction of unseen data:  [0 0]
#
# Centroids after iteration 1:  [[3.  2.5]
#  [3.  5. ]]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   """

# %% [markdown]
# ## Visualizing results after iteration 1

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6, 6))
plt.scatter(X[kmeans.labels_ == 0, 0], X[kmeans.labels_ == 0, 1], c='green', label='cluster 1')
plt.scatter(X[kmeans.labels_ == 1, 0], X[kmeans.labels_ == 1, 1], c='blue', label='cluster 2')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=300,  c='r', label='centroid')
plt.legend()

# %% [markdown]
# Do you think the visualization above is satisfying our Logic?. Justify Your Answer
#
# No, it dosent satisfy my logic as the datas are not clustered in vertically or horizontally

# %% [markdown]
# ## Sample Example with Default values

# %%
from sklearn.cluster import KMeans
import numpy as np
X = np.array([[1, 2], [1, 4], [5, 3],[5, 6]]) #Samples
kmeans = KMeans(n_clusters=2).fit(X)  #Defining and fitting K-means

print(" Cluster allocation: ",kmeans.labels_,"\n") #Will print Cluster allocation of each samples
print(" Prediction: ",kmeans.predict([[0, 0], [12, 3]]),"\n") #Predicting for unseen data
print(" Centers: ",kmeans.cluster_centers_)
# Out:
#  Cluster allocation:  [1 1 0 0]
#
#  Prediction:  [1 0]
#
#  Centers:  [[5.  4.5]
#  [1.  3. ]]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6, 6))
plt.scatter(X[kmeans.labels_ == 0, 0], X[kmeans.labels_ == 0, 1], c='green', label='cluster 1')
plt.scatter(X[kmeans.labels_ == 1, 0], X[kmeans.labels_ == 1, 1], c='blue', label='cluster 2')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=300,  c='r', label='centroid')
plt.legend()

# %% [markdown]
# #6. Assignment

# %%
#Implement K-Means for following data, Assume k=2 
from sklearn.cluster import KMeans
import numpy as np
X = np.array([[1, 2], [1, 4], [5, 3],[5, 6],[7,8],[6,2],[8,9],[4,2]]) #Samples
kmeans = KMeans(n_clusters=2).fit(X)  #Defining and fitting K-means

print(" Cluster allocation: ",kmeans.labels_,"\n") #Will print Cluster allocation of each samples
print(" Prediction: ",kmeans.predict([[0, 0], [12, 3]]),"\n") #Predicting for unseen data
print(" Centers: ",kmeans.cluster_centers_)
# Out:
#  Cluster allocation:  [1 1 1 0 0 1 0 1]
#
#  Prediction:  [1 0]
#
#  Centers:  [[6.66666667 7.66666667]
#  [3.4        2.6       ]]

# %%
# Visualizing the results
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 6))
plt.scatter(X[kmeans.labels_ == 0, 0], X[kmeans.labels_ == 0, 1], c='green', label='cluster 1')
plt.scatter(X[kmeans.labels_ == 1, 0], X[kmeans.labels_ == 1, 1], c='blue', label='cluster 2')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=300,  c='r', label='centroid')
plt.legend()

# %%
#Implement K-Means for following data, Assume k=3 and Visualize the results

from sklearn.cluster import KMeans
import numpy as np

X = np.array([[1, 2], [1, 4],[1, 0],[10, 2], [10, 4],[10, 0],[5, 3],[7,2]])
kmeans = KMeans(n_clusters=3).fit(X)  #Defining and fitting K-means

print(" Cluster allocation: ",kmeans.labels_,"\n") #Will print Cluster allocation of each samples
print(" Prediction: ",kmeans.predict([[0, 0], [12, 3]]),"\n") #Predicting for unseen data
print(" Centers: ",kmeans.cluster_centers_)
# Out:
#  Cluster allocation:  [1 1 1 0 0 0 2 2]
#
#  Prediction:  [1 0]
#
#  Centers:  [[10.   2. ]
#  [ 1.   2. ]
#  [ 6.   2.5]]

# %%
# Visualizing the results
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 6))
plt.scatter(X[kmeans.labels_ == 0, 0], X[kmeans.labels_ == 0, 1], c='green', label='cluster 1')
plt.scatter(X[kmeans.labels_ == 1, 0], X[kmeans.labels_ == 1, 1], c='blue', label='cluster 2')
plt.scatter(X[kmeans.labels_== 2, 0],  X[kmeans.labels_ == 2, 1],c='red',label='cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=300,  c='r', label='centroid')
plt.legend()

# %% [markdown]
# # 7. K-means on Simple dataset
#
# For Dataset visit link
#
# https://raw.githubusercontent.com/Jayku88/Machine-Learning-Lab/main/faithful.csv
#
# Right Click and Save As to location in your System

# %%
#Upload file to colab from your system
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0e96380a-37ba-4979-a812-8855bda2f94b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e96380a-37ba-4979-a812-8855bda2f94b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving faithful.csv to faithful (4).csv

# %%
#Converting to Dataframe
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['faithful.csv']))

# %%
#Visualizing Input Data
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
plt.scatter(df.iloc[:, 0], df.iloc[:, 1])
plt.xlabel('Eruption time in mins')
plt.ylabel('Waiting time to next eruption')
plt.title('Visualization of raw data');

# %%
#K-Means Clustering
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Standardize the data
X_std = StandardScaler().fit_transform(df)

# Run local implementation of kmeans
km = KMeans(n_clusters=2)
km.fit(X_std)
centroids = km.cluster_centers_

# Plot the clustered data
fig, ax = plt.subplots(figsize=(6, 6))
plt.scatter(X_std[km.labels_ == 0, 0], X_std[km.labels_ == 0, 1],c='green', label='cluster 1')
plt.scatter(X_std[km.labels_ == 1, 0], X_std[km.labels_ == 1, 1],c='blue', label='cluster 2')
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], marker='*', s=300, c='r', label='centroid')
plt.legend()
plt.xlim([-2, 2])
plt.ylim([-2, 2])
plt.xlabel('Eruption time in mins')
plt.ylabel('Waiting time to next eruption')
plt.title('Visualization of clustered data', fontweight='bold')
ax.set_aspect('equal');

# %% [markdown]
# # 8. Advantages and Disadvantages of K-Means Clustering
#
# **ADVANTAGES**
#
#
# *   Relatively simple to implement.
# *   Scales to large data sets.
# *   Guarantees convergence.
# *   Can warm-start the positions of centroids.
# *   Easily adapts to new examples.
# *   Generalizes to clusters of different shapes and sizes, such as elliptical clusters.
#
#
#
#
# **DISADVANTAGES**
#
#
# *   Choosing k manually
# *   Being dependent on initial values.
# *   Clustering data of varying sizes and density.
# *   Clustering outliers.
# *   Scaling with number of dimensions.

# %% [markdown]
# # Reflections
#
#
# 1.   K-Means Clustering
# 2.   Reading csv files and processing
# 1.   Visualizing K-Means results using matplotlib
# 2.   Advantages and Disadvantages of K-Means

# %%
#@title  { run: "auto", vertical-output: true }
#@title  { run: "auto", vertical-output: true }
name = "Abhjith A Thampi" #@param {type:"string"}
roll_number = "AM.EN.U4AIE20102" #@param {type:"string"}
self_assessment = 8 #@param {type:"slider", min:1, max:10, step:1}
print("Name : ",name)
print("Roll Number : ",roll_number)
print("Self Assessment Marks : ",self_assessment,"/10")
# Out:
# Name :  Abhjith A Thampi
# Roll Number :  AM.EN.U4AIE20102
# Self Assessment Marks :  8 /10
